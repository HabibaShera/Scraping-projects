# %%
import requests

import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://eg1lib.org/s/programming%20concepts'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(html_file, 'html.parser')

# %%
containers = soup.find_all('div', class_="resItemBox resItemBoxBooks exactMatch")
len(containers)
# Out:
# 50

# %%
containers[12].find_all(class_='property_label')
# Out:
# [<div class="property_label">Year:</div>,
#  <div class="property_label">Language:</div>,
#  <div class="property_label">File:</div>,
#  <div class="property_label">Your tags:</div>]

# %%
df_data = []

for container in containers:
    data= []
    data.append(container.find_all('a')[1].text)
    if container.find_all(class_='property_label')[0].text == 'Year:':
        data.append(container.find_all(class_='property_value')[0].text)
    else: data.append('None')
    data.append(container.find_all(class_='authors')[0].text)
    
    df_data.append(data)

pd.DataFrame(df_data, columns=['Title', 'Year', 'Author'])
# Out:
#                                                 Title  Year  \
# 0   Expert Python Programming: Master Python by le...  2021
# 1   Expert Python Programming, 2nd Edition: Become...  2016
# 2   Rust in Action: Systems programming concepts a...  2021
# 3   Advanced C++ Programming Cookbook: Become an e...  2020
# 4   Learn Python Programming: The Comprehensive Gu...  2021
# 5   Beginning Functional JavaScript: Uncover the C...  2018
# 6   Structural Equation Modeling with Amos: Basic ...  2016
# 7   Introduction to C++: Programming Concepts and ...  2019
# 8   Concepts, techniques, and models of computer p...  2004
# 9   Learn Java 12 Programming - A step-by-step gui...  2019
# 10        Parallel Programming: Concepts and Practice  2017
# 11  Concepts of Programming Languages, Global Edition  2015
# 12                  Concepts of Programming Languages  2019
# 13  Genetic Algorithms and Genetic Programming: Mo...  2009
# 14  SQL Server Database Programming With Visual Ba...  2020
# ...
